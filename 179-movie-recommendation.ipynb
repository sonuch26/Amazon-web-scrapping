# %% [markdown]
# <a href="https://www.kaggle.com/code/sonuchouhan/179-movie-recommendation?scriptVersionId=124995329" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import process

# %%
movies='../input/movies123/movies - movies.csv'
ratings='../input/ratings123/ratings - ratings.csv'

df_movies=pd.read_csv(movies, usecols=['movieId','title'], dtype={'movieId':'int32','title':'str'})
df_ratings=pd.read_csv(ratings, usecols=['userId','movieId','rating'],dtype={'userId':'int32','movieId':'int32','rating':'float32'})

# %%
df_movies.head()
#df_ratings.head()
#df_movies.ndim
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
#Spare Matrix
#         Users
#        [4,4,5] A
#Movies  [3,3,4] B ==   Cos(A,B) => 0.95 
#       [3,2,1]

movies_users=df_ratings.pivot(index='movieId', columns='userId',values='rating').fillna(0)
mat_movies_users=csr_matrix(movies_users.values)

# %%
# Euclidean Distance
# Manhattan Distance
# Minkowski Distance 
# Cosine Similarity
model_knn= NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20)

# %%
model_knn.fit(mat_movies_users)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %%
# Recommender(movie_name) => List of Movies recommended

def recommender(movie_name, data,model, n_recommendations ):
    model.fit(data)
    idx=process.extractOne(movie_name, df_movies['title'])[2]
    print('Movie Selected: ',df_movies['title'][idx], 'Index: ',idx)
    print('Searching for recommendations.....')
    distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendations)
    for i in indices:
        print(df_movies['title'][i].where(i!=idx))
    
recommender('kungfu panda', mat_movies_users, model_knn,20)
# Out:
# Movie Selected:  Amazing Panda Adventure, The (1995) Index:  119
# Searching for recommendations.....
# 119                                    NaN
# 178                       Wild Bill (1995)
# 187                       Cure, The (1995)
# 747                Nothing Personal (1995)
# 169                    Three Wishes (1995)
# 160                        Reckless (1995)
# 218              Jefferson in Paris (1995)
# 209                           Gordy (1995)
# 612             Spirits of the Dead (1968)
# 294               Walking Dead, The (1995)
# 317             I Like It Like That (1994)
# 445                  Poetic Justice (1993)
# 269                      Rent-a-Kid (1995)
# 662                         Carpool (1996)
# 109      NeverEnding Story III, The (1994)
# 494               Little Big League (1994)
# 49                   Big Green, The (1995)
# 310                        Crooklyn (1994)
# 399    Geronimo: An American Legend (1993)
# ...
